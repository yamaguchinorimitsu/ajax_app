# %% [markdown]
# <a href="https://colab.research.google.com/github/yamaguchinorimitsu/ajax_app/blob/master/%E3%82%B9%E3%83%83%E3%82%AD%E3%83%AA%E6%A9%9F%E6%A2%B0%E7%AC%AC%EF%BC%96%E7%AB%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/cinema.csv')

df.head(3)
# Out:
#    cinema_id   SNS1  SNS2         actor  original  sales
# 0       1375  291.0  1044   8808.994029         0   9731
# 1       1000  363.0   568  10290.709370         1  10210
# 2       1390  158.0   431   6340.388534         1   8227

# %%
df.isnull().any(axis=0)
# Out:
# cinema_id    False
# SNS1          True
# SNS2         False
# actor         True
# original     False
# sales        False
# dtype: bool

# %%
df2 = df.fillna(df.mean())

df2.isnull().any(axis=0)
# Out:
# cinema_id    False
# SNS1         False
# SNS2         False
# actor        False
# original     False
# sales        False
# dtype: bool

# %%
# JupyterLab上にグラフ描画するためのおまじない
# %matplotlib inline

# SNS2とsalesの散布図の作成
df2.plot(kind = 'scatter', x = 'SNS2', y = 'sales')
# Out:
# <Axes: xlabel='SNS2', ylabel='sales'>

# %%
for name in df2.columns:

  if name == 'chinema_id' or name == 'sales':
    continue

  df2.plot(kind = 'scatter', x = name , y = 'sales')

# %%
df[(df['SNS2']>1000) & (df['sales']<8500)]
# Out:
#     cinema_id   SNS1  SNS2        actor  original  sales
# 30       1855  149.0  1200  8173.096892         0   8000

# %%
no = df2[(df['SNS2'] > 1000 ) & (df['sales'] < 8500)].index
no
# Out:
# Int64Index([30], dtype='int64')

# %%
no = df2[(df2['SNS2'] > 1000) & (df2['sales'] < 8500)].index
df3 = df2.drop(no, axis = 0)

#インデックスの行を削除してdf3に代入

# %%
df3 = df2.drop(no, axis=0)

df3.shape
# Out:
# (99, 6)
